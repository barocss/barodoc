# %% [markdown]
# ## Asset Viewer: Jupyter Notebook Sample
#
# This notebook tests the **IPYNB viewer** with:
#
# - **Markdown cells** (rendered as HTML)
# - **Code cells** with text output (stream)
# - **Code cells** with rich output: `text/html`, `text/plain`, and image (PNG)
#
# If you see formatted markdown and outputs below, the viewer is working.

# %%
print("Hello from the asset viewer.")
print("Code cells show source + saved outputs.")
# Out:
# Hello from the asset viewer.
# Code cells show source + saved outputs.

# %%
# Simulated DataFrame-style HTML output (as Jupyter would produce)
import json
data = {"format": [".tex", ".csv", ".rst", ".ipynb"], "viewer": ["LaTeX.js", "Table", "RST", "Notebook"]}
print(json.dumps(data, indent=2))
# Out:
# {
#   "format": [".tex", ".csv", ".rst", ".ipynb"],
#   "viewer": ["LaTeX.js", "Table", "RST", "Notebook"]
# }
# {'format': ['.tex', '.csv', '.rst', '.ipynb'], 'viewer': ['LaTeX.js', 'Table', 'RST', 'Notebook']}

# %%
# Cell with both text/plain and a small image output (1x1 PNG)
print("Output with image below:")
# Out:
# Output with image below:
# '(1x1 PNG)'

# %% [markdown]
# ### Conclusion
#
# The notebook viewer should display:
#
# 1. This markdown as **HTML**
# 2. Code blocks with **stdout**
# 3. **HTML table** from `execute_result`
# 4. A tiny **image** from `display_data` (1×1 pixel)
#
# If all of the above are visible, the asset viewer is working correctly.
